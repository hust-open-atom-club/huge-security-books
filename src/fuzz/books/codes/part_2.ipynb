# %%
from Coverage import *

cgi_decode("Hello+world")
# Out:
# 'Hello world'

# %%
assert cgi_decode('+') == ' '
assert cgi_decode('%20') == ' '
assert cgi_decode('abc') == 'abc'

try:
    cgi_decode('%?a')
    assert False
except ValueError:
    pass

# %%
from Coverage import *

cgi_decode_traced("a+b")
print(coverage)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 from Coverage import *
# ----> 3 cgi_decode_traced("a+b")
#       4 print(coverage)
#
# NameError: name 'cgi_decode_traced' is not defined
