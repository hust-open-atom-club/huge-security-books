# %%
import os
import sys
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("."))))
from py_fuzz.MutationFuzzer import *
from py_fuzz.Fuzzer import *

# %%
from urllib.parse import urlparse

urlparse("http://www.google.com/search?q=fuzzing")
# Out:
# ParseResult(scheme='http', netloc='www.google.com', path='/search', params='', query='q=fuzzing', fragment='')

# %%
fuzzer(char_start=32, char_range=96)
# Out:
# "{$glwX6\\4g:V8enz'JfE.w%H^W~g8`x~j/=C#Nb$B;pS4h@P&Oq(N'PJ\x7f!Shz+o_?[`eOGu/LFbu^\\5}+m0lnMi|W!0{V"

# %%
for i in range(1000):
    try:
        url = fuzzer()
        result = http_program(url)
        print("Success!")
    except ValueError:
        pass

# %%
import os
import sys
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("."))))
from py_fuzz.MutationFuzzer import *
from py_fuzz.Fuzzer import *

for i in range(10):
    print(repr(mutate("A quick brown fox")))
# Out:
# 'A quick brown f/x'
# 'A quick browWn fox'
# 'A quick browFn fox'
# 'A quick brown\x00fox'
# 'A q4uick brown fox'
# 'A quick broEwn fox'
# 'A quik brown fox'
# ' quick brown fox'
# 'A qick brown fox'
# 'A quick brown fo~x'

# %%
import os
import sys
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("."))))
from py_fuzz.MutationFuzzer import *
from py_fuzz.Fuzzer import *

seed_input = "http://www.google.com/search?q=fuzzing"
mutation_fuzzer = MutationFuzzer(seed=[seed_input])
mutation_fuzzer.fuzz()
mutation_fuzzer.fuzz()
mutation_fuzzer.fuzz()
# Out:
# 'http:b//www.gool\\ecom/reqch?q=fuzzing'

# %%
import os
import sys
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("."))))
from py_fuzz.MutationFuzzer import *
from py_fuzz.Fuzzer import *

http_runner = FunctionRunner(http_program)
http_runner.run("https://foo.bar/")
# Out:
# (True, 'PASS')

# %%
import os
import sys
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("."))))
from py_fuzz.Coverage import *

http_runner = FunctionCoverageRunner(http_program)
http_runner.run("https://foo.bar/")
print(list(http_runner.coverage())[:5])
# Out:
# [('<lambda>', 1), ('http_program', 78), ('_coerce_args', 129), ('_noop', 109), ('urlparse', 394)]

# %%
import os
import sys
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("."))))
from py_fuzz.MutationFuzzer import MutationCoverageFuzzer

seed_input = "http://www.google.com/search?q=fuzzing"
mutation_fuzzer = MutationCoverageFuzzer(seed=[seed_input])
mutation_fuzzer.runs(http_runner, trials=10000)
mutation_fuzzer.population
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       2 import sys
#       3 sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("."))))
# ----> 4 from py_fuzz.MutationFuzzer import MutationCoverageFuzzer
#       6 seed_input = "http://www.google.com/search?q=fuzzing"
#       7 mutation_fuzzer = MutationCoverageFuzzer(seed=[seed_input])
#
# File ~/workspace/huge-security-books/src/fuzz/books/codes/py_fuzz/MutationFuzzer.py:5
#       2 from typing import Callable, List, Set
#       3 from urllib.parse import urlparse
# ----> 5 from py_fuzz.Coverage import FunctionCoverageRunner
#       6 from py_fuzz.Fuzzer import *
#       9 class MutationFuzzer(Fuzzer):
#
# File ~/workspace/huge-security-books/src/fuzz/books/codes/py_fuzz/Coverage.py:6
#       3 from types import FrameType, TracebackType
# ...
