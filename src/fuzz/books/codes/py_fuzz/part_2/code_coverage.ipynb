# %%
import os
import sys
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("."))))
from py_fuzz.Coverage import *

# %%
cgi_decode("Hello+world")

assert cgi_decode('+') == ' '
assert cgi_decode('%20') == ' '
assert cgi_decode('abc') == 'abc'

try:
    cgi_decode('%?a')
    assert False
except ValueError:
    pass

# %%
cgi_decode_traced("a+b")

# %%
import os
import sys
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath("."))))
from py_fuzz.Coverage import *

with Coverage() as cov:
    cgi_decode("a+b")

print(cov.coverage())
print(cov)
# Out:
# {('cgi_decode', 98), ('cgi_decode', 111), ('cgi_decode', 101), ('cgi_decode', 91), ('cgi_decode', 113), ('cgi_decode', 97), ('cgi_decode', 100), ('cgi_decode', 90), ('cgi_decode', 96), ('cgi_decode', 112), ('cgi_decode', 93), ('cgi_decode', 99), ('cgi_decode', 89), ('cgi_decode', 102), ('cgi_decode', 92)}
# # 82  def cgi_decode(s: str) -> str:
# # 83      """Decode the CGI-encoded string `s`:
# # 84         * replace '+' by ' '
# # 85         * replace "%xx" by the character with hex number xx.
# # 86         Return the decoded string.  Raise `ValueError` for invalid inputs."""
# # 87
# # 88      # Mapping of hex digits to their integer values
#   89      hex_values = {
#   90          '0': 0, '1': 1, '2': 2, '3': 3, '4': 4,
#   91          '5': 5, '6': 6, '7': 7, '8': 8, '9': 9,
#   92          'a': 10, 'b': 11, 'c': 12, 'd': 13, 'e': 14, 'f': 15,
#   93          'A': 10, 'B': 11, 'C': 12, 'D': 13, 'E': 14, 'F': 15,
# # 94      }
# # 95
#   96      t = ""
#   97      i = 0
#   98      while i < len(s):
#   99          c = s[i]
#   100          if c == '+':
#   101              t += ' '
#   102          elif c == '%':
# # 103              digit_high, digit_low = s[i + 1], s[i + 2]
# # 104              i += 2
# # 105              if digit_high in hex_values and digit_low in hex_values:
# # 106                  v = hex_values[digit_high] * 16 + hex_values[digit_low]
# # 107                  t += chr(v)
# # 108              else:
# # 109                  raise ValueError("Invalid encoding")
# # 110          else:
#   111              t += c
#   112          i += 1
#   113      return t

# %%
with Coverage() as cov_plus:
    cgi_decode("a+b")
with Coverage() as cov_standard:
    cgi_decode("abc")

cov_plus.coverage() - cov_standard.coverage()
# Out:
# {('cgi_decode', 101)}

# %%
with Coverage() as cov_max:
    cgi_decode('+')
    cgi_decode('%20')
    cgi_decode('abc')
    try:
        cgi_decode('%?a')
    except Exception:
        pass

cov_max.coverage() - cov_plus.coverage()
# Out:
# {('cgi_decode', 103),
#  ('cgi_decode', 104),
#  ('cgi_decode', 105),
#  ('cgi_decode', 106),
#  ('cgi_decode', 107),
#  ('cgi_decode', 109)}
